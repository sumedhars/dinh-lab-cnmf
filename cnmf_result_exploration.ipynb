# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('all_datasets_consensus/anal_pc5_c21_S2.filtered_consensus_outputs/anal_pc5_c21_S2.filtered.starcat_spectra.k_7.dt_0_01.txt', sep='\t')
df1.drop(columns={"Unnamed: 0"}, inplace=True)
df1.head()
# Out:
#         A2M  A2ML1  A3GALT2    A4GALT      AAAS      AACS      AARD      AASS  \
# 0  0.063131    NaN      NaN  0.000000  0.000000  0.000000  0.097962  0.076795
# 1  0.014548    NaN      NaN  0.103786  0.161325  0.658146  0.000000  0.000000
# 2  0.600495    NaN      NaN  0.299775  0.128391  0.000000  0.049273  0.249785
# 3  0.436655    NaN      NaN  0.014444  0.051056  0.000000  0.000000  0.000000
# 4  0.000000    NaN      NaN  0.000000  0.521959  0.000000  0.141807  0.014162
#
#        AATK     ABCA1  ...     ZNF83    ZNF831     ZNRF1   ZSCAN18    ZSCAN2  \
# 0  0.071709  0.420991  ...  0.122411  0.109487  0.053830  0.061127  0.127198
# 1  0.097148  0.000000  ...  0.010730  0.000000  0.208838  0.000000  0.110446
# 2  0.000000  0.068089  ...  0.058207  0.000000  0.000000  0.133633  0.000000
# 3  0.326425  0.765738  ...  0.064072  0.038895  0.000000  0.113754  0.000000
# 4  0.107295  0.000000  ...  0.434864  0.079165  0.456971  0.305951  0.175788
#
# ...

# %%
df1 = df1.dropna(axis='columns', how='any')
df1.head(7)
# Out:
#         A2M    A4GALT      AAAS      AACS      AARD      AASS      AATK  \
# 0  0.063131  0.000000  0.000000  0.000000  0.097962  0.076795  0.071709
# 1  0.014548  0.103786  0.161325  0.658146  0.000000  0.000000  0.097148
# 2  0.600495  0.299775  0.128391  0.000000  0.049273  0.249785  0.000000
# 3  0.436655  0.014444  0.051056  0.000000  0.000000  0.000000  0.326425
# 4  0.000000  0.000000  0.521959  0.000000  0.141807  0.014162  0.107295
# 5  1.286397  0.328970  0.527163  0.000000  0.000000  0.000287  0.000000
# 6  0.426608  0.075746  0.035027  0.000000  0.000000  0.000000  0.000000
#
#       ABCA1    ABCA10    ABCA12  ...     ZNF83    ZNF831     ZNRF1   ZSCAN18  \
# 0  0.420991  0.000000  0.000000  ...  0.122411  0.109487  0.053830  0.061127
# 1  0.000000  0.000000  0.247049  ...  0.010730  0.000000  0.208838  0.000000
# 2  0.068089  0.077601  0.062096  ...  0.058207  0.000000  0.000000  0.133633
# 3  0.765738  0.003253  0.023198  ...  0.064072  0.038895  0.000000  0.113754
# ...

# %%
df2 = pd.read_csv('all_datasets_consensus/anal_pc5_c21_S2.filtered_consensus_outputs/anal_pc5_c21_S2.filtered.starcat_spectra.k_6.dt_0_01.txt', sep='\t')
df2.drop(columns={"Unnamed: 0"}, inplace=True)
df2.head()
# Out:
#         A2M  A2ML1  A3GALT2    A4GALT      AAAS      AACS      AARD      AASS  \
# 0  0.063167    NaN      NaN  0.000000  0.000000  0.000000  0.097213  0.076559
# 1  0.014439    NaN      NaN  0.101682  0.155660  0.647258  0.000000  0.000000
# 2  0.589926    NaN      NaN  0.294815  0.123981  0.000000  0.048428  0.246666
# 3  0.430776    NaN      NaN  0.013325  0.046977  0.000000  0.000000  0.000000
# 4  0.000000    NaN      NaN  0.000000  0.502286  0.000000  0.136081  0.013482
#
#        AATK     ABCA1  ...     ZNF83    ZNF831     ZNRF1   ZSCAN18    ZSCAN2  \
# 0  0.071328  0.417216  ...  0.121987  0.108321  0.052136  0.056381  0.124675
# 1  0.095869  0.000000  ...  0.012334  0.000000  0.201386  0.000000  0.107099
# 2  0.000000  0.067357  ...  0.059788  0.000000  0.000000  0.125198  0.000000
# 3  0.322405  0.755922  ...  0.065175  0.038626  0.000000  0.104013  0.000000
# 4  0.103190  0.000000  ...  0.417661  0.075751  0.432725  0.281925  0.240638
#
# ...

# %%
df2 = df2.dropna(axis='columns', how='any')
df2.head(6)
# Out:
#         A2M    A4GALT      AAAS      AACS      AARD      AASS      AATK  \
# 0  0.063167  0.000000  0.000000  0.000000  0.097213  0.076559  0.071328
# 1  0.014439  0.101682  0.155660  0.647258  0.000000  0.000000  0.095869
# 2  0.589926  0.294815  0.123981  0.000000  0.048428  0.246666  0.000000
# 3  0.430776  0.013325  0.046977  0.000000  0.000000  0.000000  0.322405
# 4  0.000000  0.000000  0.502286  0.000000  0.136081  0.013482  0.103190
# 5  1.129664  0.275444  0.385285  0.000000  0.000000  0.000000  0.000000
#
#       ABCA1    ABCA10    ABCA12  ...     ZNF83    ZNF831     ZNRF1   ZSCAN18  \
# 0  0.417216  0.000000  0.000000  ...  0.121987  0.108321  0.052136  0.056381
# 1  0.000000  0.000000  0.238873  ...  0.012334  0.000000  0.201386  0.000000
# 2  0.067357  0.061059  0.057521  ...  0.059788  0.000000  0.000000  0.125198
# 3  0.755922  0.000000  0.019374  ...  0.065175  0.038626  0.000000  0.104013
# 4  0.000000  0.097564  0.018377  ...  0.417661  0.075751  0.432725  0.281925
# ...

# %%
# Row 0 → x values
x = df2.iloc[0]

# Row 1 → y values
y = df1.iloc[0]

plt.figure(figsize=(12, 8))
plt.scatter(x, y)

# Add labels from column names
# for gene, x_val, y_val in zip(df.columns, x, y):
#    plt.text(x_val, y_val, gene, fontsize=8)

plt.xlabel("Row 0 values")
plt.ylabel("Row 1 values")
plt.title("Scatterplot of Genes (Row0 vs Row1)")
plt.tight_layout()
plt.show()
